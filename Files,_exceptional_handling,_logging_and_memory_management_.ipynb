# %% [markdown]
# #1. What is the difference between interpreted and compiled languages?

# %% [markdown]
# * Compiled: source → compiler → The source code is translated into machine code by a compiler before execution. This results in faster startup and execution times, but the generated binary is platform-specific. Examples include C and C++.
#
# * Interpreted: The source code is executed line by line at runtime by an interpreter. This is typically slower than compiled languages, but offers greater portability and flexibility for dynamic features. Examples include Python and JavaScript.

# %% [markdown]
# # 2.  What is exception handling in Python?

# %% [markdown]
# Mechanism to detect and manage runtime errors (exceptions) using **try**, **except**, **else**, **finally** so program can continue or fail gracefully.

# %% [markdown]
# # 3.   What is the purpose of the finally block in exception handling?

# %% [markdown]
# The purpose of the finally block in exception handling in Python is to define a block of code that will always be executed, regardless of whether an exception occurred in the try block or not.
#
# This is particularly useful for cleanup operations, such as:
#
# Closing files that were opened in the try block.
# Releasing external resources.
# Ensuring that certain actions are performed even if an error interrupts the normal flow of the program.
# Think of it as a guarantee that the code within the finally block will run before the try...except statement finishes.

# %% [markdown]
# # 4.  What is logging in Python?

# %% [markdown]
# Logging in Python is a structured way to record events during program execution for debugging and monitoring.

# %% [markdown]
# # 5.  What is the significance of the __del__ method in Python?

# %% [markdown]
# The __del__ method in Python is called when an object is about to be garbage collected. It's used for cleanup operations like releasing resources (closing files, etc.). However, its use is often discouraged due to unpredictable timing and potential issues with circular references.

# %% [markdown]
# # 6 What is the difference between import and from ... import in Python?

# %% [markdown]
# * import module_name: Imports the entire module.
# * Access with module_name.object_name.
# * from module_name import object_name: Imports specific objects.
# * Access directly with object_name

# %% [markdown]
# # 7.  How can you handle multiple exceptions in Python?

# %% [markdown]
# * **Multiple `except` blocks** → Handle each exception type separately.
# * **Tuple in one `except`** → `(Type1, Type2)` for same handling.
# * **Generic `except Exception`** → Catch all (use for logging/fallback).
# * **Best practice** → Catch specific exceptions first, then generic ones.

# %% [markdown]
# # 8.  What is the purpose of the with statement when handling files in Python ?

# %% [markdown]
# The with statement in Python simplifies resource management, especially with files. It ensures resources are properly acquired and released. When used with files, it automatically closes the file, even if errors occur. This prevents resource leaks and makes code cleaner than using explicit close() calls or finally blocks.

# %% [markdown]
# # 9.  What is the difference between multithreading and multiprocessing ?

# %% [markdown]
# * Multithreading: Uses multiple threads within a single process, sharing memory. Suitable for I/O-bound tasks (limited by GIL).
# * Multiprocessing: Uses multiple independent processes, each with its own memory. Suitable for CPU-bound tasks (bypasses GIL).

# %% [markdown]
# # 10.  What are the advantages of using logging in a program ?

# %% [markdown]
# * Helps track the flow of a program
# * Makes it easy to debug errors
# * Can record warnings, errors, and info in a file
# * Better than `print()` for large applications
# * You can set log levels (INFO, DEBUG, ERROR, etc.)
# * Helps in monitoring real-time systems

# %% [markdown]
# # 11.  What is memory management in Python?

# %% [markdown]
# * Reference Counting: Tracks how many references point to an object. When the count drops to zero, the object is deallocated.
# * Garbage Collection: A cycle detection algorithm that reclaims memory occupied by objects involved in reference cycles.
# * Private Heap: All Python objects and data structures reside in a private heap.
# * Memory Allocator: Manages blocks of memory within the heap.

# %% [markdown]
# # 12.  What are the basic steps involved in exception handling in Python

# %% [markdown]
# * try: Enclose the potentially problematic code in a try block.
# * except: Define except block(s) to catch specific exceptions.
# * else (optional): Execute code in the else block if no exception occurs.
# * finally (optional): Execute code in the finally block always, for cleanup.

# %% [markdown]
# # 13.  Why is memory management important in Python?

# %% [markdown]
# Memory management in Python is important to prevent memory leaks, ensure efficient resource utilization, and contribute to the stability and reliability of applications by automatically handling memory allocation and deallocation.

# %% [markdown]
# # 14. What is the role of try and except in exception handling?

# %% [markdown]
# Role of **try**: Wraps the risky code that might throw an error
#
# Role of **except**:Catches the error if it happens in the `try` block, Prevents the program from crashing

# %% [markdown]
# # 15.  How does Python's garbage collection system work?

# %% [markdown]
# Python's garbage collection system primarily works using reference counting to track object references. When an object's reference count drops to zero, it's immediately deallocated. Additionally, a cycle detection algorithm handles objects involved in reference cycles that reference counting can't resolve.

# %% [markdown]
# # 16. What is the purpose of the else block in exception handling?

# %% [markdown]
# The else block in Python's exception handling is optional. Its purpose is to contain code that should only run if the try block completes without raising an exception.
# It provides a clear separation between code that might fail and code that executes on success.
# This helps improve code readability and structure.
# Think of it as the "all clear" section after the risky code

# %% [markdown]
# # 17.  What are the common logging levels in Python?

# %% [markdown]
# * DEBUG: Detailed information, typically of interest only when diagnosing problems.
# * INFO: Confirmation that things are working as expected.
# * WARNING: An indication that something unexpected happened, or indicative of some problem in the near future (e.g., 'disk space low'). The software is still working as expected.
# * ERROR: Due to a more serious problem, the software has not been able to perform some function.
# * CRITICAL: A serious error, indicating that the program itself may be unable to continue running.

# %% [markdown]
# # 18.  What is the difference between os.fork() and multiprocessing in Python

# %% [markdown]
# * os.fork(): Creates a new process by duplicating the current process. It's a lower-level function available on Unix-like systems.
# * multiprocessing: A higher-level, cross-platform module that provides an API for creating and managing processes, offering more features and ease of use compared to os.fork().

# %% [markdown]
# # 19.  What is the importance of closing a file in Python?

# %% [markdown]
# * Ensure all buffered data is written to the file.
# * Release the system resources held by the file.
# * Prevent potential data corruption or loss.

# %% [markdown]
# # 20.  What is the difference between file.read() and file.readline() in Python?

# %% [markdown]
# * file.read(): Reads the entire content of the file as a single string.
# * file.readline(): Reads a single line from the file at a time.

# %% [markdown]
# #21. What is the logging module in Python used for ?

# %% [markdown]
# * **Record messages** from your program (like errors, warnings, info)
# * Help in **debugging and monitoring** the app
# *  Save logs to a **file or console**
# * Control the **level of details** shown (like DEBUG, INFO, ERROR)

# %% [markdown]
# # 22. What is the os module in Python used for in file handling?

# %% [markdown]
# * Create, delete, rename files and folders
# * Check if a file/folder exists
# * Work with file paths
# * Navigate directorie

# %% [markdown]
# # 23. What are the challenges associated with memory management in Python ?

# %% [markdown]
# * Reference Cycles: Objects referencing each other can prevent deallocation by reference counting alone.
# *Unpredictable Garbage Collection: The timing of garbage collection isn't guaranteed, making cleanup with __del__ unreliable.
# *Memory Leaks: Although less common than in manual memory languages, leaks can still occur with certain patterns or external libraries.
# * Performance Overhead: While automatic, garbage collection can introduce pauses or overhead in performance-sensitive applications.
# * Debugging: Tracking down memory-related issues can be complex due to the automatic nature of management.

# %% [markdown]
# # 24.  How do you raise an exception manually in Python?

# %% [markdown]
# You can raise an exception manually in Python using the raise keyword, followed by the exception type and an optional error message. For example: raise ValueError("Something went wrong").

# %% [markdown]
# # 25. Why is it important to use multithreading in certain applications?

# %% [markdown]
#  * **Run multiple tasks at the same time**
#   (like downloading files while updating UI)
# * Improve **performance** in I/O-bound tasks
#   (e.g., reading/writing files, making API calls)
# *Make apps feel **faster and more responsive**
#  Handle **background work** without freezing the main program

# %%
with open("example.txt", "w") as file:
    file.write("Hello, this is my first file!")

print("hello its kuldeep ")
# Out:
# hello its kuldeep

# %% [markdown]
# ## 2. Write a Python program to read the contents of a file and print each line.

# %%
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, this is my first file!

# %% [markdown]
# ## 3. How could you handle a case where the file doesn't exist while trying to open it for reading.

# %%
try:
    with open("file_new.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("File not found. Please create a new file.")
# Out:
# File not found. Please create a new file.

# %% [markdown]
# ## 4. Write a Python scripts that reads from one file and write its contents to another file.

# %%
try:
    with open("example.txt", "r") as source_file:
        content = source_file.read()

    with open("copied_example.txt", "w") as destination_file:
        destination_file.write(content)

    print("Contents successfully copied from example.txt to copied_example.txt")

except FileNotFoundError:
    print("Error: The source file 'example.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Contents successfully copied from example.txt to copied_example.txt

# %% [markdown]
# ## 5. How could you catch and handle divisio by zero error in Python?

# %%
try:
    numerator = 1
    denominator = 0
    result = numerator / denominator
    print(result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: Cannot divide by zero!

# %% [markdown]
# ## 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging

logging.basicConfig(filename="error_log.txt",
                    level=logging.ERROR,
                    format="%(asctime)s - %(levelname)s - %(message)s")

try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2
    print("Result:", result)

except ZeroDivisionError:
    logging.error("Division by zero attempted.")
    print("Error: Cannot divide by zero. Check the log file for details.")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# ERROR:root:Division by zero attempted.
# Error: Cannot divide by zero. Check the log file for details.

# %% [markdown]
# ## 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using logging method.

# %%
import logging
logging.basicConfig(filename = "test_new.log", level= logging.DEBUG, format= '%(asctime)s - %(levelname)s - %(message)s')

logging.debug("This msg is for debugging..")
logging.info("This is info msg..")
logging.warning("This is warning msg..")
logging.error("This is error msg..")

logging.shutdown()
# Out:
# WARNING:root:This is warning msg..
# ERROR:root:This is error msg..

# %% [markdown]
# ## 8. WAP to handle a file opening error using exception handling.

# %%
try:
    filename = input("Enter the file name: ")
    with open(filename, 'r') as file:
        content = file.read()
        print("File content:\n", content)

except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")

except PermissionError:
    print(f"Error: You do not have permission to open '{filename}'.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter the file name: data analyst
# Error: The file 'data analyst' was not found.

# %% [markdown]
# ## 9. How can you read a file line by line and store its content in a list in Python?

# %%
with open("example.txt", "r") as file:
    lines = file.readlines()

# Remove newline characters
lines = [line.strip() for line in lines]

print("File content as list:")
print(lines)
# Out:
# File content as list:
# ['Hello, this is my first file!']

# %% [markdown]
# ## 10. How can you append data to an existing file in Python?

# %%
with open("example.txt", "a") as file:
    file.write("\nThis is new content being appended.")

print("Data appended successfully!")
# Out:
# Data appended successfully!

# %% [markdown]
# ## 11. Write a program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exists.

# %%
# Sample dictionary
student = {
    "name": "kuldeep",
    "age": 28,
    "course": "Data Analytical"
}

try:
    key = input("Enter the dictionary key you want to access: ")
    value = student[key]
    print(f"The value for '{key}' is: {value}")

except KeyError:
    print(f"Error: The key '{key}' does not exist in the dictionary.")
# Out:
# Enter the dictionary key you want to access: marks
# Error: The key 'marks' does not exist in the dictionary.

# %% [markdown]
# ## 12. WAP to demonstrate using multiple except blocks to handle different types of exceptions.

# %%
try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2
    print("Result:", result)

    filename = input("Enter file name to open: ")
    with open(filename, 'r') as file:
        content = file.read()
        print("File content:\n", content)

except ValueError:
    print("Error: Invalid input. Please enter valid numbers.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except FileNotFoundError:
    print("Error: The file was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter numerator: 5
# Enter denominator: 2
# Result: 2.5
# Enter file name to open: e
# Error: The file was not found.

# %% [markdown]
# ## 14. WAP that uses the logging module to log both informational and error messages.

# %%
try:
    logging.info("Program started.")

    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2

    logging.info(f"Division successful: {num1} / {num2} = {result}")
    print("Result:", result)

except ZeroDivisionError:
    logging.error("Attempted division by zero.")
    print("Error: Cannot divide by zero.")

except ValueError:
    logging.error("Invalid input. Non-numeric value entered.")
    print("Error: Please enter valid numbers.")

logging.info("Program finished.")
# Out:
# Enter numerator: 4.5
# ERROR:root:Invalid input. Non-numeric value entered.
# Error: Please enter valid numbers.

# %% [markdown]
# ## 15. WAP that prints the content of a file and handles the case when the file is empty.

# %%
file_path = "example.txt"

try:
    with open(file_path, "r") as file:
        content = file.read()
        if content.strip() == "":
            print("The file is empty.")
        else:
            print("File content:")
            print(content)
except FileNotFoundError:
    print("File not found.")
# Out:
# File content:
# Hello, this is my first file!
# This is new content being appended.

# %% [markdown]
# ## 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
pip install memory_profiler

# %%
from memory_profiler import profile

@profile
def create_large_list():
    data = [i for i in range(1000000)]  # Large list to consume memory
    return data

@profile
def main():
    my_list = create_large_list()
    print("List created with", len(my_list), "items.")

if __name__ == "__main__":
    main()

# %%
python -m memory_profiler your_script.py

# %% [markdown]
# ## 17. WAP to create and write a list of numbers to a file , one number per line.

# %%
numbers = [10, 20, 30, 40, 50]

with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(str(num) + "\n")

print("Numbers written to numbers.txt successfully!")
# Out:
# Numbers written to numbers.txt successfully!

# %% [markdown]
# ## 18. How would you implement a basic logging setup that logs to a file with rotatio after 1 MB?

# %%
import logging
from logging.handlers import RotatingFileHandler


handler = RotatingFileHandler(
    "app.log",       # Log file name
    maxBytes=1_000_000,  # 1 MB
    backupCount=3        # Keep last 3 backups
)

formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logger.addHandler(handler)

for i in range(5000):
    logger.info(f"Log entry number {i}")
# Out:
# INFO:root:Log entry number 0
# INFO:root:Log entry number 1
# INFO:root:Log entry number 2
# INFO:root:Log entry number 3
# INFO:root:Log entry number 4
# INFO:root:Log entry number 5
# INFO:root:Log entry number 6
# INFO:root:Log entry number 7
# INFO:root:Log entry number 8
# INFO:root:Log entry number 9
# INFO:root:Log entry number 10
# INFO:root:Log entry number 11
# INFO:root:Log entry number 12
# INFO:root:Log entry number 13
# INFO:root:Log entry number 14
# INFO:root:Log entry number 15
# INFO:root:Log entry number 16
# INFO:root:Log entry number 17
# INFO:root:Log entry number 18
# INFO:root:Log entry number 19
# INFO:root:Log entry number 20
# INFO:root:Log entry number 21
# INFO:root:Log entry number 22
# INFO:root:Log entry number 23
# INFO:root:Log entry number 24
# INFO:root:Log entry number 25
# INFO:root:Log entry number 26
# INFO:root:Log entry number 27
# INFO:root:Log entry number 28
# INFO:root:Log entry number 29
# INFO:root:Log entry number 30
# INFO:root:Log entry number 31
# INFO:root:Log entry number 32
# INFO:root:Log entry number 33
# INFO:root:Log entry number 34
# INFO:root:Log entry number 35
# INFO:root:Log entry number 36
# INFO:root:Log entry number 37
# INFO:root:Log entry number 38
# INFO:root:Log entry number 39
# INFO:root:Log entry number 40
# INFO:root:Log entry number 41
# INFO:root:Log entry number 42
# INFO:root:Log entry number 43
# INFO:root:Log entry number 44
# INFO:root:Log entry number 45
# INFO:root:Log entry number 46
# INFO:root:Log entry number 47
# INFO:root:Log entry number 48
# INFO:root:Log entry number 49
# INFO:root:Log entry number 50
# INFO:root:Log entry number 51
# INFO:root:Log entry number 52
# INFO:root:Log entry number 53
# INFO:root:Log entry number 54
# INFO:root:Log entry number 55
# INFO:root:Log entry number 56
# INFO:root:Log entry number 57
# INFO:root:Log entry number 58
# INFO:root:Log entry number 59
# INFO:root:Log entry number 60
# INFO:root:Log entry number 61
# INFO:root:Log entry number 62
# INFO:root:Log entry number 63
# INFO:root:Log entry number 64
# INFO:root:Log entry number 65
# INFO:root:Log entry number 66
# INFO:root:Log entry number 67
# INFO:root:Log entry number 68
# INFO:root:Log entry number 69
# INFO:root:Log entry number 70
# INFO:root:Log entry number 71
# INFO:root:Log entry number 72
# INFO:root:Log entry number 73
# INFO:root:Log entry number 74
# INFO:root:Log entry number 75
# INFO:root:Log entry number 76
# INFO:root:Log entry number 77
# INFO:root:Log entry number 78
# INFO:root:Log entry number 79
# INFO:root:Log entry number 80
# INFO:root:Log entry number 81
# INFO:root:Log entry number 82
# INFO:root:Log entry number 83
# INFO:root:Log entry number 84
# INFO:root:Log entry number 85
# INFO:root:Log entry number 86
# INFO:root:Log entry number 87
# INFO:root:Log entry number 88
# INFO:root:Log entry number 89
# INFO:root:Log entry number 90
# INFO:root:Log entry number 91
# INFO:root:Log entry number 92
# INFO:root:Log entry number 93
# INFO:root:Log entry number 94
# INFO:root:Log entry number 95
# INFO:root:Log entry number 96
# INFO:root:Log entry number 97
# INFO:root:Log entry number 98
# INFO:root:Log entry number 99
# INFO:root:Log entry number 100
# INFO:root:Log entry number 101
# INFO:root:Log entry number 102
# INFO:root:Log entry number 103
# INFO:root:Log entry number 104
# INFO:root:Log entry number 105
# INFO:root:Log entry number 106
# INFO:root:Log entry number 107
# INFO:root:Log entry number 108
# INFO:root:Log entry number 109
# INFO:root:Log entry number 110
# INFO:root:Log entry number 111
# INFO:root:Log entry number 112
# INFO:root:Log entry number 113
# INFO:root:Log entry number 114
# INFO:root:Log entry number 115
# INFO:root:Log entry number 116
# INFO:root:Log entry number 117
# INFO:root:Log entry number 118
# INFO:root:Log entry number 119
# INFO:root:Log entry number 120
# INFO:root:Log entry number 121
# INFO:root:Log entry number 122
# INFO:root:Log entry number 123
# INFO:root:Log entry number 124
# INFO:root:Log entry number 125
# INFO:root:Log entry number 126
# INFO:root:Log entry number 127
# INFO:root:Log entry number 128
# INFO:root:Log entry number 129
# INFO:root:Log entry number 130
# INFO:root:Log entry number 131
# INFO:root:Log entry number 132
# INFO:root:Log entry number 133
# INFO:root:Log entry number 134
# INFO:root:Log entry number 135
# INFO:root:Log entry number 136
# INFO:root:Log entry number 137
# INFO:root:Log entry number 138
# INFO:root:Log entry number 139
# INFO:root:Log entry number 140
# INFO:root:Log entry number 141
# INFO:root:Log entry number 142
# INFO:root:Log entry number 143
# INFO:root:Log entry number 144
# INFO:root:Log entry number 145
# INFO:root:Log entry number 146
# INFO:root:Log entry number 147
# INFO:root:Log entry number 148
# INFO:root:Log entry number 149
# INFO:root:Log entry number 150
# INFO:root:Log entry number 151
# INFO:root:Log entry number 152
# INFO:root:Log entry number 153
# INFO:root:Log entry number 154
# INFO:root:Log entry number 155
# INFO:root:Log entry number 156
# INFO:root:Log entry number 157
# INFO:root:Log entry number 158
# INFO:root:Log entry number 159
# INFO:root:Log entry number 160
# INFO:root:Log entry number 161
# INFO:root:Log entry number 162
# INFO:root:Log entry number 163
# INFO:root:Log entry number 164
# INFO:root:Log entry number 165
# INFO:root:Log entry number 166
# INFO:root:Log entry number 167
# INFO:root:Log entry number 168
# INFO:root:Log entry number 169
# INFO:root:Log entry number 170
# INFO:root:Log entry number 171
# INFO:root:Log entry number 172
# INFO:root:Log entry number 173
# INFO:root:Log entry number 174
# INFO:root:Log entry number 175
# INFO:root:Log entry number 176
# INFO:root:Log entry number 177
# INFO:root:Log entry number 178
# INFO:root:Log entry number 179
# INFO:root:Log entry number 180
# INFO:root:Log entry number 181
# INFO:root:Log entry number 182
# INFO:root:Log entry number 183
# INFO:root:Log entry number 184
# INFO:root:Log entry number 185
# INFO:root:Log entry number 186
# INFO:root:Log entry number 187
# INFO:root:Log entry number 188
# INFO:root:Log entry number 189
# INFO:root:Log entry number 190
# INFO:root:Log entry number 191
# INFO:root:Log entry number 192
# INFO:root:Log entry number 193
# INFO:root:Log entry number 194
# INFO:root:Log entry number 195
# INFO:root:Log entry number 196
# INFO:root:Log entry number 197
# INFO:root:Log entry number 198
# INFO:root:Log entry number 199
# INFO:root:Log entry number 200
# INFO:root:Log entry number 201
# INFO:root:Log entry number 202
# INFO:root:Log entry number 203
# INFO:root:Log entry number 204
# INFO:root:Log entry number 205
# INFO:root:Log entry number 206
# INFO:root:Log entry number 207
# INFO:root:Log entry number 208
# INFO:root:Log entry number 209
# INFO:root:Log entry number 210
# INFO:root:Log entry number 211
# INFO:root:Log entry number 212
# INFO:root:Log entry number 213
# INFO:root:Log entry number 214
# INFO:root:Log entry number 215
# INFO:root:Log entry number 216
# INFO:root:Log entry number 217
# INFO:root:Log entry number 218
# INFO:root:Log entry number 219
# INFO:root:Log entry number 220
# INFO:root:Log entry number 221
# INFO:root:Log entry number 222
# INFO:root:Log entry number 223
# INFO:root:Log entry number 224
# INFO:root:Log entry number 225
# INFO:root:Log entry number 226
# INFO:root:Log entry number 227
# INFO:root:Log entry number 228
# INFO:root:Log entry number 229
# INFO:root:Log entry number 230
# INFO:root:Log entry number 231
# INFO:root:Log entry number 232
# INFO:root:Log entry number 233
# INFO:root:Log entry number 234
# INFO:root:Log entry number 235
# INFO:root:Log entry number 236
# INFO:root:Log entry number 237
# INFO:root:Log entry number 238
# INFO:root:Log entry number 239
# INFO:root:Log entry number 240
# INFO:root:Log entry number 241
# INFO:root:Log entry number 242
# INFO:root:Log entry number 243
# INFO:root:Log entry number 244
# INFO:root:Log entry number 245
# INFO:root:Log entry number 246
# INFO:root:Log entry number 247
# INFO:root:Log entry number 248
# INFO:root:Log entry number 249
# INFO:root:Log entry number 250
# INFO:root:Log entry number 251
# INFO:root:Log entry number 252
# INFO:root:Log entry number 253
# INFO:root:Log entry number 254
# INFO:root:Log entry number 255
# INFO:root:Log entry number 256
# INFO:root:Log entry number 257
# INFO:root:Log entry number 258
# INFO:root:Log entry number 259
# INFO:root:Log entry number 260
# INFO:root:Log entry number 261
# INFO:root:Log entry number 262
# INFO:root:Log entry number 263
# INFO:root:Log entry number 264
# INFO:root:Log entry number 265
# INFO:root:Log entry number 266
# INFO:root:Log entry number 267
# INFO:root:Log entry number 268
# INFO:root:Log entry number 269
# INFO:root:Log entry number 270
# INFO:root:Log entry number 271
# INFO:root:Log entry number 272
# INFO:root:Log entry number 273
# INFO:root:Log entry number 274
# INFO:root:Log entry number 275
# INFO:root:Log entry number 276
# INFO:root:Log entry number 277
# INFO:root:Log entry number 278
# INFO:root:Log entry number 279
# INFO:root:Log entry number 280
# INFO:root:Log entry number 281
# INFO:root:Log entry number 282
# INFO:root:Log entry number 283
# INFO:root:Log entry number 284
# INFO:root:Log entry number 285
# INFO:root:Log entry number 286
# INFO:root:Log entry number 287
# INFO:root:Log entry number 288
# INFO:root:Log entry number 289
# INFO:root:Log entry number 290
# INFO:root:Log entry number 291
# INFO:root:Log entry number 292
# INFO:root:Log entry number 293
# INFO:root:Log entry number 294
# INFO:root:Log entry number 295
# INFO:root:Log entry number 296
# INFO:root:Log entry number 297
# INFO:root:Log entry number 298
# INFO:root:Log entry number 299
# INFO:root:Log entry number 300
# INFO:root:Log entry number 301
# INFO:root:Log entry number 302
# INFO:root:Log entry number 303
# INFO:root:Log entry number 304
# INFO:root:Log entry number 305
# INFO:root:Log entry number 306
# INFO:root:Log entry number 307
# INFO:root:Log entry number 308
# INFO:root:Log entry number 309
# INFO:root:Log entry number 310
# INFO:root:Log entry number 311
# INFO:root:Log entry number 312
# INFO:root:Log entry number 313
# INFO:root:Log entry number 314
# INFO:root:Log entry number 315
# INFO:root:Log entry number 316
# INFO:root:Log entry number 317
# INFO:root:Log entry number 318
# INFO:root:Log entry number 319
# INFO:root:Log entry number 320
# INFO:root:Log entry number 321
# INFO:root:Log entry number 322
# INFO:root:Log entry number 323
# INFO:root:Log entry number 324
# INFO:root:Log entry number 325
# INFO:root:Log entry number 326
# INFO:root:Log entry number 327
# INFO:root:Log entry number 328
# INFO:root:Log entry number 329
# INFO:root:Log entry number 330
# INFO:root:Log entry number 331
# INFO:root:Log entry number 332
# INFO:root:Log entry number 333
# INFO:root:Log entry number 334
# INFO:root:Log entry number 335
# INFO:root:Log entry number 336
# INFO:root:Log entry number 337
# INFO:root:Log entry number 338
# INFO:root:Log entry number 339
# INFO:root:Log entry number 340
# INFO:root:Log entry number 341
# INFO:root:Log entry number 342
# INFO:root:Log entry number 343
# INFO:root:Log entry number 344
# INFO:root:Log entry number 345
# INFO:root:Log entry number 346
# INFO:root:Log entry number 347
# INFO:root:Log entry number 348
# INFO:root:Log entry number 349
# INFO:root:Log entry number 350
# INFO:root:Log entry number 351
# INFO:root:Log entry number 352
# INFO:root:Log entry number 353
# INFO:root:Log entry number 354
# INFO:root:Log entry number 355
# INFO:root:Log entry number 356
# INFO:root:Log entry number 357
# INFO:root:Log entry number 358
# INFO:root:Log entry number 359
# INFO:root:Log entry number 360
# INFO:root:Log entry number 361
# INFO:root:Log entry number 362
# INFO:root:Log entry number 363
# INFO:root:Log entry number 364
# INFO:root:Log entry number 365
# INFO:root:Log entry number 366
# INFO:root:Log entry number 367
# INFO:root:Log entry number 368
# INFO:root:Log entry number 369
# INFO:root:Log entry number 370
# INFO:root:Log entry number 371
# INFO:root:Log entry number 372
# INFO:root:Log entry number 373
# INFO:root:Log entry number 374
# INFO:root:Log entry number 375
# INFO:root:Log entry number 376
# INFO:root:Log entry number 377
# INFO:root:Log entry number 378
# INFO:root:Log entry number 379
# INFO:root:Log entry number 380
# INFO:root:Log entry number 381
# INFO:root:Log entry number 382
# INFO:root:Log entry number 383
# INFO:root:Log entry number 384
# INFO:root:Log entry number 385
# INFO:root:Log entry number 386
# INFO:root:Log entry number 387
# INFO:root:Log entry number 388
# INFO:root:Log entry number 389
# INFO:root:Log entry number 390
# INFO:root:Log entry number 391
# INFO:root:Log entry number 392
# INFO:root:Log entry number 393
# INFO:root:Log entry number 394
# INFO:root:Log entry number 395
# INFO:root:Log entry number 396
# INFO:root:Log entry number 397
# INFO:root:Log entry number 398
# INFO:root:Log entry number 399
# INFO:root:Log entry number 400
# INFO:root:Log entry number 401
# INFO:root:Log entry number 402
# INFO:root:Log entry number 403
# INFO:root:Log entry number 404
# INFO:root:Log entry number 405
# INFO:root:Log entry number 406
# INFO:root:Log entry number 407
# INFO:root:Log entry number 408
# INFO:root:Log entry number 409
# INFO:root:Log entry number 410
# INFO:root:Log entry number 411
# INFO:root:Log entry number 412
# INFO:root:Log entry number 413
# INFO:root:Log entry number 414
# INFO:root:Log entry number 415
# INFO:root:Log entry number 416
# INFO:root:Log entry number 417
# INFO:root:Log entry number 418
# INFO:root:Log entry number 419
# INFO:root:Log entry number 420
# INFO:root:Log entry number 421
# INFO:root:Log entry number 422
# INFO:root:Log entry number 423
# INFO:root:Log entry number 424
# INFO:root:Log entry number 425
# INFO:root:Log entry number 426
# INFO:root:Log entry number 427
# INFO:root:Log entry number 428
# INFO:root:Log entry number 429
# INFO:root:Log entry number 430
# INFO:root:Log entry number 431
# INFO:root:Log entry number 432
# INFO:root:Log entry number 433
# INFO:root:Log entry number 434
# INFO:root:Log entry number 435
# INFO:root:Log entry number 436
# INFO:root:Log entry number 437
# INFO:root:Log entry number 438
# INFO:root:Log entry number 439
# INFO:root:Log entry number 440
# INFO:root:Log entry number 441
# INFO:root:Log entry number 442
# INFO:root:Log entry number 443
# INFO:root:Log entry number 444
# INFO:root:Log entry number 445
# INFO:root:Log entry number 446
# INFO:root:Log entry number 447
# INFO:root:Log entry number 448
# INFO:root:Log entry number 449
# INFO:root:Log entry number 450
# INFO:root:Log entry number 451
# INFO:root:Log entry number 452
# INFO:root:Log entry number 453
# INFO:root:Log entry number 454
# INFO:root:Log entry number 455
# INFO:root:Log entry number 456
# INFO:root:Log entry number 457
# INFO:root:Log entry number 458
# INFO:root:Log entry number 459
# INFO:root:Log entry number 460
# INFO:root:Log entry number 461
# INFO:root:Log entry number 462
# INFO:root:Log entry number 463
# INFO:root:Log entry number 464
# INFO:root:Log entry number 465
# INFO:root:Log entry number 466
# INFO:root:Log entry number 467
# INFO:root:Log entry number 468
# INFO:root:Log entry number 469
# INFO:root:Log entry number 470
# INFO:root:Log entry number 471
# INFO:root:Log entry number 472
# INFO:root:Log entry number 473
# INFO:root:Log entry number 474
# INFO:root:Log entry number 475
# INFO:root:Log entry number 476
# INFO:root:Log entry number 477
# INFO:root:Log entry number 478
# INFO:root:Log entry number 479
# INFO:root:Log entry number 480
# INFO:root:Log entry number 481
# INFO:root:Log entry number 482
# INFO:root:Log entry number 483
# INFO:root:Log entry number 484
# INFO:root:Log entry number 485
# INFO:root:Log entry number 486
# INFO:root:Log entry number 487
# INFO:root:Log entry number 488
# INFO:root:Log entry number 489
# INFO:root:Log entry number 490
# INFO:root:Log entry number 491
# INFO:root:Log entry number 492
# INFO:root:Log entry number 493
# INFO:root:Log entry number 494
# INFO:root:Log entry number 495
# INFO:root:Log entry number 496
# INFO:root:Log entry number 497
# INFO:root:Log entry number 498
# INFO:root:Log entry number 499
# INFO:root:Log entry number 500
# INFO:root:Log entry number 501
# INFO:root:Log entry number 502
# INFO:root:Log entry number 503
# INFO:root:Log entry number 504
# INFO:root:Log entry number 505
# INFO:root:Log entry number 506
# INFO:root:Log entry number 507
# INFO:root:Log entry number 508
# INFO:root:Log entry number 509
# INFO:root:Log entry number 510
# INFO:root:Log entry number 511
# INFO:root:Log entry number 512
# INFO:root:Log entry number 513
# INFO:root:Log entry number 514
# INFO:root:Log entry number 515
# INFO:root:Log entry number 516
# INFO:root:Log entry number 517
# INFO:root:Log entry number 518
# INFO:root:Log entry number 519
# INFO:root:Log entry number 520
# INFO:root:Log entry number 521
# INFO:root:Log entry number 522
# INFO:root:Log entry number 523
# INFO:root:Log entry number 524
# INFO:root:Log entry number 525
# INFO:root:Log entry number 526
# INFO:root:Log entry number 527
# INFO:root:Log entry number 528
# INFO:root:Log entry number 529
# INFO:root:Log entry number 530
# INFO:root:Log entry number 531
# INFO:root:Log entry number 532
# INFO:root:Log entry number 533
# INFO:root:Log entry number 534
# INFO:root:Log entry number 535
# INFO:root:Log entry number 536
# INFO:root:Log entry number 537
# INFO:root:Log entry number 538
# INFO:root:Log entry number 539
# INFO:root:Log entry number 540
# INFO:root:Log entry number 541
# INFO:root:Log entry number 542
# INFO:root:Log entry number 543
# INFO:root:Log entry number 544
# INFO:root:Log entry number 545
# INFO:root:Log entry number 546
# INFO:root:Log entry number 547
# INFO:root:Log entry number 548
# INFO:root:Log entry number 549
# INFO:root:Log entry number 550
# INFO:root:Log entry number 551
# INFO:root:Log entry number 552
# INFO:root:Log entry number 553
# INFO:root:Log entry number 554
# INFO:root:Log entry number 555
# INFO:root:Log entry number 556
# INFO:root:Log entry number 557
# INFO:root:Log entry number 558
# INFO:root:Log entry number 559
# INFO:root:Log entry number 560
# INFO:root:Log entry number 561
# INFO:root:Log entry number 562
# INFO:root:Log entry number 563
# INFO:root:Log entry number 564
# INFO:root:Log entry number 565
# INFO:root:Log entry number 566
# INFO:root:Log entry number 567
# INFO:root:Log entry number 568
# INFO:root:Log entry number 569
# INFO:root:Log entry number 570
# INFO:root:Log entry number 571
# INFO:root:Log entry number 572
# INFO:root:Log entry number 573
# INFO:root:Log entry number 574
# INFO:root:Log entry number 575
# INFO:root:Log entry number 576
# INFO:root:Log entry number 577
# INFO:root:Log entry number 578
# INFO:root:Log entry number 579
# INFO:root:Log entry number 580
# INFO:root:Log entry number 581
# INFO:root:Log entry number 582
# INFO:root:Log entry number 583
# INFO:root:Log entry number 584
# INFO:root:Log entry number 585
# INFO:root:Log entry number 586
# INFO:root:Log entry number 587
# INFO:root:Log entry number 588
# INFO:root:Log entry number 589
# INFO:root:Log entry number 590
# INFO:root:Log entry number 591
# INFO:root:Log entry number 592
# INFO:root:Log entry number 593
# INFO:root:Log entry number 594
# INFO:root:Log entry number 595
# INFO:root:Log entry number 596
# INFO:root:Log entry number 597
# INFO:root:Log entry number 598
# INFO:root:Log entry number 599
# INFO:root:Log entry number 600
# INFO:root:Log entry number 601
# INFO:root:Log entry number 602
# INFO:root:Log entry number 603
# INFO:root:Log entry number 604
# INFO:root:Log entry number 605
# INFO:root:Log entry number 606
# INFO:root:Log entry number 607
# INFO:root:Log entry number 608
# INFO:root:Log entry number 609
# INFO:root:Log entry number 610
# INFO:root:Log entry number 611
# INFO:root:Log entry number 612
# INFO:root:Log entry number 613
# INFO:root:Log entry number 614
# INFO:root:Log entry number 615
# INFO:root:Log entry number 616
# INFO:root:Log entry number 617
# INFO:root:Log entry number 618
# INFO:root:Log entry number 619
# INFO:root:Log entry number 620
# INFO:root:Log entry number 621
# INFO:root:Log entry number 622
# INFO:root:Log entry number 623
# INFO:root:Log entry number 624
# INFO:root:Log entry number 625
# INFO:root:Log entry number 626
# INFO:root:Log entry number 627
# INFO:root:Log entry number 628
# INFO:root:Log entry number 629
# INFO:root:Log entry number 630
# INFO:root:Log entry number 631
# INFO:root:Log entry number 632
# INFO:root:Log entry number 633
# INFO:root:Log entry number 634
# INFO:root:Log entry number 635
# INFO:root:Log entry number 636
# INFO:root:Log entry number 637
# INFO:root:Log entry number 638
# INFO:root:Log entry number 639
# INFO:root:Log entry number 640
# INFO:root:Log entry number 641
# INFO:root:Log entry number 642
# INFO:root:Log entry number 643
# INFO:root:Log entry number 644
# INFO:root:Log entry number 645
# INFO:root:Log entry number 646
# INFO:root:Log entry number 647
# INFO:root:Log entry number 648
# INFO:root:Log entry number 649
# INFO:root:Log entry number 650
# INFO:root:Log entry number 651
# INFO:root:Log entry number 652
# INFO:root:Log entry number 653
# INFO:root:Log entry number 654
# INFO:root:Log entry number 655
# INFO:root:Log entry number 656
# INFO:root:Log entry number 657
# INFO:root:Log entry number 658
# INFO:root:Log entry number 659
# INFO:root:Log entry number 660
# INFO:root:Log entry number 661
# INFO:root:Log entry number 662
# INFO:root:Log entry number 663
# INFO:root:Log entry number 664
# INFO:root:Log entry number 665
# INFO:root:Log entry number 666
# INFO:root:Log entry number 667
# INFO:root:Log entry number 668
# INFO:root:Log entry number 669
# INFO:root:Log entry number 670
# INFO:root:Log entry number 671
# INFO:root:Log entry number 672
# INFO:root:Log entry number 673
# INFO:root:Log entry number 674
# INFO:root:Log entry number 675
# INFO:root:Log entry number 676
# INFO:root:Log entry number 677
# INFO:root:Log entry number 678
# INFO:root:Log entry number 679
# INFO:root:Log entry number 680
# INFO:root:Log entry number 681
# INFO:root:Log entry number 682
# INFO:root:Log entry number 683
# INFO:root:Log entry number 684
# INFO:root:Log entry number 685
# INFO:root:Log entry number 686
# INFO:root:Log entry number 687
# INFO:root:Log entry number 688
# INFO:root:Log entry number 689
# INFO:root:Log entry number 690
# INFO:root:Log entry number 691
# INFO:root:Log entry number 692
# INFO:root:Log entry number 693
# INFO:root:Log entry number 694
# INFO:root:Log entry number 695
# INFO:root:Log entry number 696
# INFO:root:Log entry number 697
# INFO:root:Log entry number 698
# INFO:root:Log entry number 699
# INFO:root:Log entry number 700
# INFO:root:Log entry number 701
# INFO:root:Log entry number 702
# INFO:root:Log entry number 703
# INFO:root:Log entry number 704
# INFO:root:Log entry number 705
# INFO:root:Log entry number 706
# INFO:root:Log entry number 707
# INFO:root:Log entry number 708
# INFO:root:Log entry number 709
# INFO:root:Log entry number 710
# INFO:root:Log entry number 711
# INFO:root:Log entry number 712
# INFO:root:Log entry number 713
# INFO:root:Log entry number 714
# INFO:root:Log entry number 715
# INFO:root:Log entry number 716
# INFO:root:Log entry number 717
# INFO:root:Log entry number 718
# INFO:root:Log entry number 719
# INFO:root:Log entry number 720
# INFO:root:Log entry number 721
# INFO:root:Log entry number 722
# INFO:root:Log entry number 723
# INFO:root:Log entry number 724
# INFO:root:Log entry number 725
# INFO:root:Log entry number 726
# INFO:root:Log entry number 727
# INFO:root:Log entry number 728
# INFO:root:Log entry number 729
# INFO:root:Log entry number 730
# INFO:root:Log entry number 731
# INFO:root:Log entry number 732
# INFO:root:Log entry number 733
# INFO:root:Log entry number 734
# INFO:root:Log entry number 735
# INFO:root:Log entry number 736
# INFO:root:Log entry number 737
# INFO:root:Log entry number 738
# INFO:root:Log entry number 739
# INFO:root:Log entry number 740
# INFO:root:Log entry number 741
# INFO:root:Log entry number 742
# INFO:root:Log entry number 743
# INFO:root:Log entry number 744
# INFO:root:Log entry number 745
# INFO:root:Log entry number 746
# INFO:root:Log entry number 747
# INFO:root:Log entry number 748
# INFO:root:Log entry number 749
# INFO:root:Log entry number 750
# INFO:root:Log entry number 751
# INFO:root:Log entry number 752
# INFO:root:Log entry number 753
# INFO:root:Log entry number 754
# INFO:root:Log entry number 755
# INFO:root:Log entry number 756
# INFO:root:Log entry number 757
# INFO:root:Log entry number 758
# INFO:root:Log entry number 759
# INFO:root:Log entry number 760
# INFO:root:Log entry number 761
# INFO:root:Log entry number 762
# INFO:root:Log entry number 763
# INFO:root:Log entry number 764
# INFO:root:Log entry number 765
# INFO:root:Log entry number 766
# INFO:root:Log entry number 767
# INFO:root:Log entry number 768
# INFO:root:Log entry number 769
# INFO:root:Log entry number 770
# INFO:root:Log entry number 771
# INFO:root:Log entry number 772
# INFO:root:Log entry number 773
# INFO:root:Log entry number 774
# INFO:root:Log entry number 775
# INFO:root:Log entry number 776
# INFO:root:Log entry number 777
# INFO:root:Log entry number 778
# INFO:root:Log entry number 779
# INFO:root:Log entry number 780
# INFO:root:Log entry number 781
# INFO:root:Log entry number 782
# INFO:root:Log entry number 783
# INFO:root:Log entry number 784
# INFO:root:Log entry number 785
# INFO:root:Log entry number 786
# INFO:root:Log entry number 787
# INFO:root:Log entry number 788
# INFO:root:Log entry number 789
# INFO:root:Log entry number 790
# INFO:root:Log entry number 791
# INFO:root:Log entry number 792
# INFO:root:Log entry number 793
# INFO:root:Log entry number 794
# INFO:root:Log entry number 795
# INFO:root:Log entry number 796
# INFO:root:Log entry number 797
# INFO:root:Log entry number 798
# INFO:root:Log entry number 799
# INFO:root:Log entry number 800
# INFO:root:Log entry number 801
# INFO:root:Log entry number 802
# INFO:root:Log entry number 803
# INFO:root:Log entry number 804
# INFO:root:Log entry number 805
# INFO:root:Log entry number 806
# INFO:root:Log entry number 807
# INFO:root:Log entry number 808
# INFO:root:Log entry number 809
# INFO:root:Log entry number 810
# INFO:root:Log entry number 811
# INFO:root:Log entry number 812
# INFO:root:Log entry number 813
# INFO:root:Log entry number 814
# INFO:root:Log entry number 815
# INFO:root:Log entry number 816
# INFO:root:Log entry number 817
# INFO:root:Log entry number 818
# INFO:root:Log entry number 819
# INFO:root:Log entry number 820
# INFO:root:Log entry number 821
# INFO:root:Log entry number 822
# INFO:root:Log entry number 823
# INFO:root:Log entry number 824
# INFO:root:Log entry number 825
# INFO:root:Log entry number 826
# INFO:root:Log entry number 827
# INFO:root:Log entry number 828
# INFO:root:Log entry number 829
# INFO:root:Log entry number 830
# INFO:root:Log entry number 831
# INFO:root:Log entry number 832
# INFO:root:Log entry number 833
# INFO:root:Log entry number 834
# INFO:root:Log entry number 835
# INFO:root:Log entry number 836
# INFO:root:Log entry number 837
# INFO:root:Log entry number 838
# INFO:root:Log entry number 839
# INFO:root:Log entry number 840
# INFO:root:Log entry number 841
# INFO:root:Log entry number 842
# INFO:root:Log entry number 843
# INFO:root:Log entry number 844
# INFO:root:Log entry number 845
# INFO:root:Log entry number 846
# INFO:root:Log entry number 847
# INFO:root:Log entry number 848
# INFO:root:Log entry number 849
# INFO:root:Log entry number 850
# INFO:root:Log entry number 851
# INFO:root:Log entry number 852
# INFO:root:Log entry number 853
# INFO:root:Log entry number 854
# INFO:root:Log entry number 855
# INFO:root:Log entry number 856
# INFO:root:Log entry number 857
# INFO:root:Log entry number 858
# INFO:root:Log entry number 859
# INFO:root:Log entry number 860
# INFO:root:Log entry number 861
# INFO:root:Log entry number 862
# INFO:root:Log entry number 863
# INFO:root:Log entry number 864
# INFO:root:Log entry number 865
# INFO:root:Log entry number 866
# INFO:root:Log entry number 867
# INFO:root:Log entry number 868
# INFO:root:Log entry number 869
# INFO:root:Log entry number 870
# INFO:root:Log entry number 871
# INFO:root:Log entry number 872
# INFO:root:Log entry number 873
# INFO:root:Log entry number 874
# INFO:root:Log entry number 875
# INFO:root:Log entry number 876
# INFO:root:Log entry number 877
# INFO:root:Log entry number 878
# INFO:root:Log entry number 879
# INFO:root:Log entry number 880
# INFO:root:Log entry number 881
# INFO:root:Log entry number 882
# INFO:root:Log entry number 883
# INFO:root:Log entry number 884
# INFO:root:Log entry number 885
# INFO:root:Log entry number 886
# INFO:root:Log entry number 887
# INFO:root:Log entry number 888
# INFO:root:Log entry number 889
# INFO:root:Log entry number 890
# INFO:root:Log entry number 891
# INFO:root:Log entry number 892
# INFO:root:Log entry number 893
# INFO:root:Log entry number 894
# INFO:root:Log entry number 895
# INFO:root:Log entry number 896
# INFO:root:Log entry number 897
# INFO:root:Log entry number 898
# INFO:root:Log entry number 899
# INFO:root:Log entry number 900
# INFO:root:Log entry number 901
# INFO:root:Log entry number 902
# INFO:root:Log entry number 903
# INFO:root:Log entry number 904
# INFO:root:Log entry number 905
# INFO:root:Log entry number 906
# INFO:root:Log entry number 907
# INFO:root:Log entry number 908
# INFO:root:Log entry number 909
# INFO:root:Log entry number 910
# INFO:root:Log entry number 911
# INFO:root:Log entry number 912
# INFO:root:Log entry number 913
# INFO:root:Log entry number 914
# INFO:root:Log entry number 915
# INFO:root:Log entry number 916
# INFO:root:Log entry number 917
# INFO:root:Log entry number 918
# INFO:root:Log entry number 919
# INFO:root:Log entry number 920
# INFO:root:Log entry number 921
# INFO:root:Log entry number 922
# INFO:root:Log entry number 923
# INFO:root:Log entry number 924
# INFO:root:Log entry number 925
# INFO:root:Log entry number 926
# INFO:root:Log entry number 927
# INFO:root:Log entry number 928
# INFO:root:Log entry number 929
# INFO:root:Log entry number 930
# INFO:root:Log entry number 931
# INFO:root:Log entry number 932
# INFO:root:Log entry number 933
# INFO:root:Log entry number 934
# INFO:root:Log entry number 935
# INFO:root:Log entry number 936
# INFO:root:Log entry number 937
# INFO:root:Log entry number 938
# INFO:root:Log entry number 939
# INFO:root:Log entry number 940
# INFO:root:Log entry number 941
# INFO:root:Log entry number 942
# INFO:root:Log entry number 943
# INFO:root:Log entry number 944
# INFO:root:Log entry number 945
# INFO:root:Log entry number 946
# INFO:root:Log entry number 947
# INFO:root:Log entry number 948
# INFO:root:Log entry number 949
# INFO:root:Log entry number 950
# INFO:root:Log entry number 951
# INFO:root:Log entry number 952
# INFO:root:Log entry number 953
# INFO:root:Log entry number 954
# INFO:root:Log entry number 955
# INFO:root:Log entry number 956
# INFO:root:Log entry number 957
# INFO:root:Log entry number 958
# INFO:root:Log entry number 959
# INFO:root:Log entry number 960
# INFO:root:Log entry number 961
# INFO:root:Log entry number 962
# INFO:root:Log entry number 963
# INFO:root:Log entry number 964
# INFO:root:Log entry number 965
# INFO:root:Log entry number 966
# INFO:root:Log entry number 967
# INFO:root:Log entry number 968
# INFO:root:Log entry number 969
# INFO:root:Log entry number 970
# INFO:root:Log entry number 971
# INFO:root:Log entry number 972
# INFO:root:Log entry number 973
# INFO:root:Log entry number 974
# INFO:root:Log entry number 975
# INFO:root:Log entry number 976
# INFO:root:Log entry number 977
# INFO:root:Log entry number 978
# INFO:root:Log entry number 979
# INFO:root:Log entry number 980
# INFO:root:Log entry number 981
# INFO:root:Log entry number 982
# INFO:root:Log entry number 983
# INFO:root:Log entry number 984
# INFO:root:Log entry number 985
# INFO:root:Log entry number 986
# INFO:root:Log entry number 987
# INFO:root:Log entry number 988
# INFO:root:Log entry number 989
# INFO:root:Log entry number 990
# INFO:root:Log entry number 991
# INFO:root:Log entry number 992
# INFO:root:Log entry number 993
# INFO:root:Log entry number 994
# INFO:root:Log entry number 995
# INFO:root:Log entry number 996
# INFO:root:Log entry number 997
# INFO:root:Log entry number 998
# INFO:root:Log entry number 999
# INFO:root:Log entry number 1000
# INFO:root:Log entry number 1001
# INFO:root:Log entry number 1002
# INFO:root:Log entry number 1003
# INFO:root:Log entry number 1004
# INFO:root:Log entry number 1005
# INFO:root:Log entry number 1006
# INFO:root:Log entry number 1007
# INFO:root:Log entry number 1008
# INFO:root:Log entry number 1009
# INFO:root:Log entry number 1010
# INFO:root:Log entry number 1011
# INFO:root:Log entry number 1012
# INFO:root:Log entry number 1013
# INFO:root:Log entry number 1014
# INFO:root:Log entry number 1015
# INFO:root:Log entry number 1016
# INFO:root:Log entry number 1017
# INFO:root:Log entry number 1018
# INFO:root:Log entry number 1019
# INFO:root:Log entry number 1020
# INFO:root:Log entry number 1021
# INFO:root:Log entry number 1022
# INFO:root:Log entry number 1023
# INFO:root:Log entry number 1024
# INFO:root:Log entry number 1025
# INFO:root:Log entry number 1026
# INFO:root:Log entry number 1027
# INFO:root:Log entry number 1028
# INFO:root:Log entry number 1029
# INFO:root:Log entry number 1030
# INFO:root:Log entry number 1031
# INFO:root:Log entry number 1032
# INFO:root:Log entry number 1033
# INFO:root:Log entry number 1034
# INFO:root:Log entry number 1035
# INFO:root:Log entry number 1036
# INFO:root:Log entry number 1037
# INFO:root:Log entry number 1038
# INFO:root:Log entry number 1039
# INFO:root:Log entry number 1040
# INFO:root:Log entry number 1041
# INFO:root:Log entry number 1042
# INFO:root:Log entry number 1043
# INFO:root:Log entry number 1044
# INFO:root:Log entry number 1045
# INFO:root:Log entry number 1046
# INFO:root:Log entry number 1047
# INFO:root:Log entry number 1048
# INFO:root:Log entry number 1049
# INFO:root:Log entry number 1050
# INFO:root:Log entry number 1051
# INFO:root:Log entry number 1052
# INFO:root:Log entry number 1053
# INFO:root:Log entry number 1054
# INFO:root:Log entry number 1055
# INFO:root:Log entry number 1056
# INFO:root:Log entry number 1057
# INFO:root:Log entry number 1058
# INFO:root:Log entry number 1059
# INFO:root:Log entry number 1060
# INFO:root:Log entry number 1061
# INFO:root:Log entry number 1062
# INFO:root:Log entry number 1063
# INFO:root:Log entry number 1064
# INFO:root:Log entry number 1065
# INFO:root:Log entry number 1066
# INFO:root:Log entry number 1067
# INFO:root:Log entry number 1068
# INFO:root:Log entry number 1069
# INFO:root:Log entry number 1070
# INFO:root:Log entry number 1071
# INFO:root:Log entry number 1072
# INFO:root:Log entry number 1073
# INFO:root:Log entry number 1074
# INFO:root:Log entry number 1075
# INFO:root:Log entry number 1076
# INFO:root:Log entry number 1077
# INFO:root:Log entry number 1078
# INFO:root:Log entry number 1079
# INFO:root:Log entry number 1080
# INFO:root:Log entry number 1081
# INFO:root:Log entry number 1082
# INFO:root:Log entry number 1083
# INFO:root:Log entry number 1084
# INFO:root:Log entry number 1085
# INFO:root:Log entry number 1086
# INFO:root:Log entry number 1087
# INFO:root:Log entry number 1088
# INFO:root:Log entry number 1089
# INFO:root:Log entry number 1090
# INFO:root:Log entry number 1091
# INFO:root:Log entry number 1092
# INFO:root:Log entry number 1093
# INFO:root:Log entry number 1094
# INFO:root:Log entry number 1095
# INFO:root:Log entry number 1096
# INFO:root:Log entry number 1097
# INFO:root:Log entry number 1098
# INFO:root:Log entry number 1099
# INFO:root:Log entry number 1100
# INFO:root:Log entry number 1101
# INFO:root:Log entry number 1102
# INFO:root:Log entry number 1103
# INFO:root:Log entry number 1104
# INFO:root:Log entry number 1105
# INFO:root:Log entry number 1106
# INFO:root:Log entry number 1107
# INFO:root:Log entry number 1108
# INFO:root:Log entry number 1109
# INFO:root:Log entry number 1110
# INFO:root:Log entry number 1111
# INFO:root:Log entry number 1112
# INFO:root:Log entry number 1113
# INFO:root:Log entry number 1114
# INFO:root:Log entry number 1115
# INFO:root:Log entry number 1116
# INFO:root:Log entry number 1117
# INFO:root:Log entry number 1118
# INFO:root:Log entry number 1119
# INFO:root:Log entry number 1120
# INFO:root:Log entry number 1121
# INFO:root:Log entry number 1122
# INFO:root:Log entry number 1123
# INFO:root:Log entry number 1124
# INFO:root:Log entry number 1125
# INFO:root:Log entry number 1126
# INFO:root:Log entry number 1127
# INFO:root:Log entry number 1128
# INFO:root:Log entry number 1129
# INFO:root:Log entry number 1130
# INFO:root:Log entry number 1131
# INFO:root:Log entry number 1132
# INFO:root:Log entry number 1133
# INFO:root:Log entry number 1134
# INFO:root:Log entry number 1135
# INFO:root:Log entry number 1136
# INFO:root:Log entry number 1137
# INFO:root:Log entry number 1138
# INFO:root:Log entry number 1139
# INFO:root:Log entry number 1140
# INFO:root:Log entry number 1141
# INFO:root:Log entry number 1142
# INFO:root:Log entry number 1143
# INFO:root:Log entry number 1144
# INFO:root:Log entry number 1145
# INFO:root:Log entry number 1146
# INFO:root:Log entry number 1147
# INFO:root:Log entry number 1148
# INFO:root:Log entry number 1149
# INFO:root:Log entry number 1150
# INFO:root:Log entry number 1151
# INFO:root:Log entry number 1152
# INFO:root:Log entry number 1153
# INFO:root:Log entry number 1154
# INFO:root:Log entry number 1155
# INFO:root:Log entry number 1156
# INFO:root:Log entry number 1157
# INFO:root:Log entry number 1158
# INFO:root:Log entry number 1159
# INFO:root:Log entry number 1160
# INFO:root:Log entry number 1161
# INFO:root:Log entry number 1162
# INFO:root:Log entry number 1163
# INFO:root:Log entry number 1164
# INFO:root:Log entry number 1165
# INFO:root:Log entry number 1166
# INFO:root:Log entry number 1167
# INFO:root:Log entry number 1168
# INFO:root:Log entry number 1169
# INFO:root:Log entry number 1170
# INFO:root:Log entry number 1171
# INFO:root:Log entry number 1172
# INFO:root:Log entry number 1173
# INFO:root:Log entry number 1174
# INFO:root:Log entry number 1175
# INFO:root:Log entry number 1176
# INFO:root:Log entry number 1177
# INFO:root:Log entry number 1178
# INFO:root:Log entry number 1179
# INFO:root:Log entry number 1180
# INFO:root:Log entry number 1181
# INFO:root:Log entry number 1182
# INFO:root:Log entry number 1183
# INFO:root:Log entry number 1184
# INFO:root:Log entry number 1185
# INFO:root:Log entry number 1186
# INFO:root:Log entry number 1187
# INFO:root:Log entry number 1188
# INFO:root:Log entry number 1189
# INFO:root:Log entry number 1190
# INFO:root:Log entry number 1191
# INFO:root:Log entry number 1192
# INFO:root:Log entry number 1193
# INFO:root:Log entry number 1194
# INFO:root:Log entry number 1195
# INFO:root:Log entry number 1196
# INFO:root:Log entry number 1197
# INFO:root:Log entry number 1198
# INFO:root:Log entry number 1199
# INFO:root:Log entry number 1200
# INFO:root:Log entry number 1201
# INFO:root:Log entry number 1202
# INFO:root:Log entry number 1203
# INFO:root:Log entry number 1204
# INFO:root:Log entry number 1205
# INFO:root:Log entry number 1206
# INFO:root:Log entry number 1207
# INFO:root:Log entry number 1208
# INFO:root:Log entry number 1209
# INFO:root:Log entry number 1210
# INFO:root:Log entry number 1211
# INFO:root:Log entry number 1212
# INFO:root:Log entry number 1213
# INFO:root:Log entry number 1214
# INFO:root:Log entry number 1215
# INFO:root:Log entry number 1216
# INFO:root:Log entry number 1217
# INFO:root:Log entry number 1218
# INFO:root:Log entry number 1219
# INFO:root:Log entry number 1220
# INFO:root:Log entry number 1221
# INFO:root:Log entry number 1222
# INFO:root:Log entry number 1223
# INFO:root:Log entry number 1224
# INFO:root:Log entry number 1225
# INFO:root:Log entry number 1226
# INFO:root:Log entry number 1227
# INFO:root:Log entry number 1228
# INFO:root:Log entry number 1229
# INFO:root:Log entry number 1230
# INFO:root:Log entry number 1231
# INFO:root:Log entry number 1232
# INFO:root:Log entry number 1233
# INFO:root:Log entry number 1234
# INFO:root:Log entry number 1235
# INFO:root:Log entry number 1236
# INFO:root:Log entry number 1237
# INFO:root:Log entry number 1238
# INFO:root:Log entry number 1239
# INFO:root:Log entry number 1240
# INFO:root:Log entry number 1241
# INFO:root:Log entry number 1242
# INFO:root:Log entry number 1243
# INFO:root:Log entry number 1244
# INFO:root:Log entry number 1245
# INFO:root:Log entry number 1246
# INFO:root:Log entry number 1247
# INFO:root:Log entry number 1248
# INFO:root:Log entry number 1249
# INFO:root:Log entry number 1250
# INFO:root:Log entry number 1251
# INFO:root:Log entry number 1252
# INFO:root:Log entry number 1253
# INFO:root:Log entry number 1254
# INFO:root:Log entry number 1255
# INFO:root:Log entry number 1256
# INFO:root:Log entry number 1257
# INFO:root:Log entry number 1258
# INFO:root:Log entry number 1259
# INFO:root:Log entry number 1260
# INFO:root:Log entry number 1261
# INFO:root:Log entry number 1262
# INFO:root:Log entry number 1263
# INFO:root:Log entry number 1264
# INFO:root:Log entry number 1265
# INFO:root:Log entry number 1266
# INFO:root:Log entry number 1267
# INFO:root:Log entry number 1268
# INFO:root:Log entry number 1269
# INFO:root:Log entry number 1270
# INFO:root:Log entry number 1271
# INFO:root:Log entry number 1272
# INFO:root:Log entry number 1273
# INFO:root:Log entry number 1274
# INFO:root:Log entry number 1275
# INFO:root:Log entry number 1276
# INFO:root:Log entry number 1277
# INFO:root:Log entry number 1278
# INFO:root:Log entry number 1279
# INFO:root:Log entry number 1280
# INFO:root:Log entry number 1281
# INFO:root:Log entry number 1282
# INFO:root:Log entry number 1283
# INFO:root:Log entry number 1284
# INFO:root:Log entry number 1285
# INFO:root:Log entry number 1286
# INFO:root:Log entry number 1287
# INFO:root:Log entry number 1288
# INFO:root:Log entry number 1289
# INFO:root:Log entry number 1290
# INFO:root:Log entry number 1291
# INFO:root:Log entry number 1292
# INFO:root:Log entry number 1293
# INFO:root:Log entry number 1294
# INFO:root:Log entry number 1295
# INFO:root:Log entry number 1296
# INFO:root:Log entry number 1297
# INFO:root:Log entry number 1298
# INFO:root:Log entry number 1299
# INFO:root:Log entry number 1300
# INFO:root:Log entry number 1301
# INFO:root:Log entry number 1302
# INFO:root:Log entry number 1303
# INFO:root:Log entry number 1304
# INFO:root:Log entry number 1305
# INFO:root:Log entry number 1306
# INFO:root:Log entry number 1307
# INFO:root:Log entry number 1308
# INFO:root:Log entry number 1309
# INFO:root:Log entry number 1310
# INFO:root:Log entry number 1311
# INFO:root:Log entry number 1312
# INFO:root:Log entry number 1313
# INFO:root:Log entry number 1314
# INFO:root:Log entry number 1315
# INFO:root:Log entry number 1316
# INFO:root:Log entry number 1317
# INFO:root:Log entry number 1318
# INFO:root:Log entry number 1319
# INFO:root:Log entry number 1320
# INFO:root:Log entry number 1321
# INFO:root:Log entry number 1322
# INFO:root:Log entry number 1323
# INFO:root:Log entry number 1324
# INFO:root:Log entry number 1325
# INFO:root:Log entry number 1326
# INFO:root:Log entry number 1327
# INFO:root:Log entry number 1328
# INFO:root:Log entry number 1329
# INFO:root:Log entry number 1330
# INFO:root:Log entry number 1331
# INFO:root:Log entry number 1332
# INFO:root:Log entry number 1333
# INFO:root:Log entry number 1334
# INFO:root:Log entry number 1335
# INFO:root:Log entry number 1336
# INFO:root:Log entry number 1337
# INFO:root:Log entry number 1338
# INFO:root:Log entry number 1339
# INFO:root:Log entry number 1340
# INFO:root:Log entry number 1341
# INFO:root:Log entry number 1342
# INFO:root:Log entry number 1343
# INFO:root:Log entry number 1344
# INFO:root:Log entry number 1345
# INFO:root:Log entry number 1346
# INFO:root:Log entry number 1347
# INFO:root:Log entry number 1348
# INFO:root:Log entry number 1349
# INFO:root:Log entry number 1350
# INFO:root:Log entry number 1351
# INFO:root:Log entry number 1352
# INFO:root:Log entry number 1353
# INFO:root:Log entry number 1354
# INFO:root:Log entry number 1355
# INFO:root:Log entry number 1356
# INFO:root:Log entry number 1357
# INFO:root:Log entry number 1358
# INFO:root:Log entry number 1359
# INFO:root:Log entry number 1360
# INFO:root:Log entry number 1361
# INFO:root:Log entry number 1362
# INFO:root:Log entry number 1363
# INFO:root:Log entry number 1364
# INFO:root:Log entry number 1365
# INFO:root:Log entry number 1366
# INFO:root:Log entry number 1367
# INFO:root:Log entry number 1368
# INFO:root:Log entry number 1369
# INFO:root:Log entry number 1370
# INFO:root:Log entry number 1371
# INFO:root:Log entry number 1372
# INFO:root:Log entry number 1373
# INFO:root:Log entry number 1374
# INFO:root:Log entry number 1375
# INFO:root:Log entry number 1376
# INFO:root:Log entry number 1377
# INFO:root:Log entry number 1378
# INFO:root:Log entry number 1379
# INFO:root:Log entry number 1380
# INFO:root:Log entry number 1381
# INFO:root:Log entry number 1382
# INFO:root:Log entry number 1383
# INFO:root:Log entry number 1384
# INFO:root:Log entry number 1385
# INFO:root:Log entry number 1386
# INFO:root:Log entry number 1387
# INFO:root:Log entry number 1388
# INFO:root:Log entry number 1389
# INFO:root:Log entry number 1390
# INFO:root:Log entry number 1391
# INFO:root:Log entry number 1392
# INFO:root:Log entry number 1393
# INFO:root:Log entry number 1394
# INFO:root:Log entry number 1395
# INFO:root:Log entry number 1396
# INFO:root:Log entry number 1397
# INFO:root:Log entry number 1398
# INFO:root:Log entry number 1399
# INFO:root:Log entry number 1400
# INFO:root:Log entry number 1401
# INFO:root:Log entry number 1402
# INFO:root:Log entry number 1403
# INFO:root:Log entry number 1404
# INFO:root:Log entry number 1405
# INFO:root:Log entry number 1406
# INFO:root:Log entry number 1407
# INFO:root:Log entry number 1408
# INFO:root:Log entry number 1409
# INFO:root:Log entry number 1410
# INFO:root:Log entry number 1411
# INFO:root:Log entry number 1412
# INFO:root:Log entry number 1413
# INFO:root:Log entry number 1414
# INFO:root:Log entry number 1415
# INFO:root:Log entry number 1416
# INFO:root:Log entry number 1417
# INFO:root:Log entry number 1418
# INFO:root:Log entry number 1419
# INFO:root:Log entry number 1420
# INFO:root:Log entry number 1421
# INFO:root:Log entry number 1422
# INFO:root:Log entry number 1423
# INFO:root:Log entry number 1424
# INFO:root:Log entry number 1425
# INFO:root:Log entry number 1426
# INFO:root:Log entry number 1427
# INFO:root:Log entry number 1428
# INFO:root:Log entry number 1429
# INFO:root:Log entry number 1430
# INFO:root:Log entry number 1431
# INFO:root:Log entry number 1432
# INFO:root:Log entry number 1433
# INFO:root:Log entry number 1434
# INFO:root:Log entry number 1435
# INFO:root:Log entry number 1436
# INFO:root:Log entry number 1437
# INFO:root:Log entry number 1438
# INFO:root:Log entry number 1439
# INFO:root:Log entry number 1440
# INFO:root:Log entry number 1441
# INFO:root:Log entry number 1442
# INFO:root:Log entry number 1443
# INFO:root:Log entry number 1444
# INFO:root:Log entry number 1445
# INFO:root:Log entry number 1446
# INFO:root:Log entry number 1447
# INFO:root:Log entry number 1448
# INFO:root:Log entry number 1449
# INFO:root:Log entry number 1450
# INFO:root:Log entry number 1451
# INFO:root:Log entry number 1452
# INFO:root:Log entry number 1453
# INFO:root:Log entry number 1454
# INFO:root:Log entry number 1455
# INFO:root:Log entry number 1456
# INFO:root:Log entry number 1457
# INFO:root:Log entry number 1458
# INFO:root:Log entry number 1459
# INFO:root:Log entry number 1460
# INFO:root:Log entry number 1461
# INFO:root:Log entry number 1462
# INFO:root:Log entry number 1463
# INFO:root:Log entry number 1464
# INFO:root:Log entry number 1465
# INFO:root:Log entry number 1466
# INFO:root:Log entry number 1467
# INFO:root:Log entry number 1468
# INFO:root:Log entry number 1469
# INFO:root:Log entry number 1470
# INFO:root:Log entry number 1471
# INFO:root:Log entry number 1472
# INFO:root:Log entry number 1473
# INFO:root:Log entry number 1474
# INFO:root:Log entry number 1475
# INFO:root:Log entry number 1476
# INFO:root:Log entry number 1477
# INFO:root:Log entry number 1478
# INFO:root:Log entry number 1479
# INFO:root:Log entry number 1480
# INFO:root:Log entry number 1481
# INFO:root:Log entry number 1482
# INFO:root:Log entry number 1483
# INFO:root:Log entry number 1484
# INFO:root:Log entry number 1485
# INFO:root:Log entry number 1486
# INFO:root:Log entry number 1487
# INFO:root:Log entry number 1488
# INFO:root:Log entry number 1489
# INFO:root:Log entry number 1490
# INFO:root:Log entry number 1491
# INFO:root:Log entry number 1492
# INFO:root:Log entry number 1493
# INFO:root:Log entry number 1494
# INFO:root:Log entry number 1495
# INFO:root:Log entry number 1496
# INFO:root:Log entry number 1497
# INFO:root:Log entry number 1498
# INFO:root:Log entry number 1499
# INFO:root:Log entry number 1500
# INFO:root:Log entry number 1501
# INFO:root:Log entry number 1502
# INFO:root:Log entry number 1503
# INFO:root:Log entry number 1504
# INFO:root:Log entry number 1505
# INFO:root:Log entry number 1506
# INFO:root:Log entry number 1507
# INFO:root:Log entry number 1508
# INFO:root:Log entry number 1509
# INFO:root:Log entry number 1510
# INFO:root:Log entry number 1511
# INFO:root:Log entry number 1512
# INFO:root:Log entry number 1513
# INFO:root:Log entry number 1514
# INFO:root:Log entry number 1515
# INFO:root:Log entry number 1516
# INFO:root:Log entry number 1517
# INFO:root:Log entry number 1518
# INFO:root:Log entry number 1519
# INFO:root:Log entry number 1520
# INFO:root:Log entry number 1521
# INFO:root:Log entry number 1522
# INFO:root:Log entry number 1523
# INFO:root:Log entry number 1524
# INFO:root:Log entry number 1525
# INFO:root:Log entry number 1526
# INFO:root:Log entry number 1527
# INFO:root:Log entry number 1528
# INFO:root:Log entry number 1529
# INFO:root:Log entry number 1530
# INFO:root:Log entry number 1531
# INFO:root:Log entry number 1532
# INFO:root:Log entry number 1533
# ...
# INFO:root:Log entry number 4500
# INFO:root:Log entry number 4501
# INFO:root:Log entry number 4502
# INFO:root:Log entry number 4503
# INFO:root:Log entry number 4504
# INFO:root:Log entry number 4505
# INFO:root:Log entry number 4506
# INFO:root:Log entry number 4507
# INFO:root:Log entry number 4508
# INFO:root:Log entry number 4509
# INFO:root:Log entry number 4510
# INFO:root:Log entry number 4511
# INFO:root:Log entry number 4512
# INFO:root:Log entry number 4513
# INFO:root:Log entry number 4514
# INFO:root:Log entry number 4515
# INFO:root:Log entry number 4516
# INFO:root:Log entry number 4517
# INFO:root:Log entry number 4518
# INFO:root:Log entry number 4519
# INFO:root:Log entry number 4520
# INFO:root:Log entry number 4521
# INFO:root:Log entry number 4522
# INFO:root:Log entry number 4523
# INFO:root:Log entry number 4524
# INFO:root:Log entry number 4525
# INFO:root:Log entry number 4526
# INFO:root:Log entry number 4527
# INFO:root:Log entry number 4528
# INFO:root:Log entry number 4529
# INFO:root:Log entry number 4530
# INFO:root:Log entry number 4531
# INFO:root:Log entry number 4532
# INFO:root:Log entry number 4533
# INFO:root:Log entry number 4534
# INFO:root:Log entry number 4535
# INFO:root:Log entry number 4536
# INFO:root:Log entry number 4537
# INFO:root:Log entry number 4538
# INFO:root:Log entry number 4539
# INFO:root:Log entry number 4540
# INFO:root:Log entry number 4541
# INFO:root:Log entry number 4542
# INFO:root:Log entry number 4543
# INFO:root:Log entry number 4544
# INFO:root:Log entry number 4545
# INFO:root:Log entry number 4546
# INFO:root:Log entry number 4547
# INFO:root:Log entry number 4548
# INFO:root:Log entry number 4549
# INFO:root:Log entry number 4550
# INFO:root:Log entry number 4551
# INFO:root:Log entry number 4552
# INFO:root:Log entry number 4553
# INFO:root:Log entry number 4554
# INFO:root:Log entry number 4555
# INFO:root:Log entry number 4556
# INFO:root:Log entry number 4557
# INFO:root:Log entry number 4558
# INFO:root:Log entry number 4559
# INFO:root:Log entry number 4560
# INFO:root:Log entry number 4561
# INFO:root:Log entry number 4562
# INFO:root:Log entry number 4563
# INFO:root:Log entry number 4564
# INFO:root:Log entry number 4565
# INFO:root:Log entry number 4566
# INFO:root:Log entry number 4567
# INFO:root:Log entry number 4568
# INFO:root:Log entry number 4569
# INFO:root:Log entry number 4570
# INFO:root:Log entry number 4571
# INFO:root:Log entry number 4572
# INFO:root:Log entry number 4573
# INFO:root:Log entry number 4574
# INFO:root:Log entry number 4575
# INFO:root:Log entry number 4576
# INFO:root:Log entry number 4577
# INFO:root:Log entry number 4578
# INFO:root:Log entry number 4579
# INFO:root:Log entry number 4580
# INFO:root:Log entry number 4581
# INFO:root:Log entry number 4582
# INFO:root:Log entry number 4583
# INFO:root:Log entry number 4584
# INFO:root:Log entry number 4585
# INFO:root:Log entry number 4586
# INFO:root:Log entry number 4587
# INFO:root:Log entry number 4588
# INFO:root:Log entry number 4589
# INFO:root:Log entry number 4590
# INFO:root:Log entry number 4591
# INFO:root:Log entry number 4592
# INFO:root:Log entry number 4593
# INFO:root:Log entry number 4594
# INFO:root:Log entry number 4595
# INFO:root:Log entry number 4596
# INFO:root:Log entry number 4597
# INFO:root:Log entry number 4598
# INFO:root:Log entry number 4599
# INFO:root:Log entry number 4600
# INFO:root:Log entry number 4601
# INFO:root:Log entry number 4602
# INFO:root:Log entry number 4603
# INFO:root:Log entry number 4604
# INFO:root:Log entry number 4605
# INFO:root:Log entry number 4606
# INFO:root:Log entry number 4607
# INFO:root:Log entry number 4608
# INFO:root:Log entry number 4609
# INFO:root:Log entry number 4610
# INFO:root:Log entry number 4611
# INFO:root:Log entry number 4612
# INFO:root:Log entry number 4613
# INFO:root:Log entry number 4614
# INFO:root:Log entry number 4615
# INFO:root:Log entry number 4616
# INFO:root:Log entry number 4617
# INFO:root:Log entry number 4618
# INFO:root:Log entry number 4619
# INFO:root:Log entry number 4620
# INFO:root:Log entry number 4621
# INFO:root:Log entry number 4622
# INFO:root:Log entry number 4623
# INFO:root:Log entry number 4624
# INFO:root:Log entry number 4625
# INFO:root:Log entry number 4626
# INFO:root:Log entry number 4627
# INFO:root:Log entry number 4628
# INFO:root:Log entry number 4629
# INFO:root:Log entry number 4630
# INFO:root:Log entry number 4631
# INFO:root:Log entry number 4632
# INFO:root:Log entry number 4633
# INFO:root:Log entry number 4634
# INFO:root:Log entry number 4635
# INFO:root:Log entry number 4636
# INFO:root:Log entry number 4637
# INFO:root:Log entry number 4638
# INFO:root:Log entry number 4639
# INFO:root:Log entry number 4640
# INFO:root:Log entry number 4641
# INFO:root:Log entry number 4642
# INFO:root:Log entry number 4643
# INFO:root:Log entry number 4644
# INFO:root:Log entry number 4645
# INFO:root:Log entry number 4646
# INFO:root:Log entry number 4647
# INFO:root:Log entry number 4648
# INFO:root:Log entry number 4649
# INFO:root:Log entry number 4650
# INFO:root:Log entry number 4651
# INFO:root:Log entry number 4652
# INFO:root:Log entry number 4653
# INFO:root:Log entry number 4654
# INFO:root:Log entry number 4655
# INFO:root:Log entry number 4656
# INFO:root:Log entry number 4657
# INFO:root:Log entry number 4658
# INFO:root:Log entry number 4659
# INFO:root:Log entry number 4660
# INFO:root:Log entry number 4661
# INFO:root:Log entry number 4662
# INFO:root:Log entry number 4663
# INFO:root:Log entry number 4664
# INFO:root:Log entry number 4665
# INFO:root:Log entry number 4666
# INFO:root:Log entry number 4667
# INFO:root:Log entry number 4668
# INFO:root:Log entry number 4669
# INFO:root:Log entry number 4670
# INFO:root:Log entry number 4671
# INFO:root:Log entry number 4672
# INFO:root:Log entry number 4673
# INFO:root:Log entry number 4674
# INFO:root:Log entry number 4675
# INFO:root:Log entry number 4676
# INFO:root:Log entry number 4677
# INFO:root:Log entry number 4678
# INFO:root:Log entry number 4679
# INFO:root:Log entry number 4680
# INFO:root:Log entry number 4681
# INFO:root:Log entry number 4682
# INFO:root:Log entry number 4683
# INFO:root:Log entry number 4684
# INFO:root:Log entry number 4685
# INFO:root:Log entry number 4686
# INFO:root:Log entry number 4687
# INFO:root:Log entry number 4688
# INFO:root:Log entry number 4689
# INFO:root:Log entry number 4690
# INFO:root:Log entry number 4691
# INFO:root:Log entry number 4692
# INFO:root:Log entry number 4693
# INFO:root:Log entry number 4694
# INFO:root:Log entry number 4695
# INFO:root:Log entry number 4696
# INFO:root:Log entry number 4697
# INFO:root:Log entry number 4698
# INFO:root:Log entry number 4699
# INFO:root:Log entry number 4700
# INFO:root:Log entry number 4701
# INFO:root:Log entry number 4702
# INFO:root:Log entry number 4703
# INFO:root:Log entry number 4704
# INFO:root:Log entry number 4705
# INFO:root:Log entry number 4706
# INFO:root:Log entry number 4707
# INFO:root:Log entry number 4708
# INFO:root:Log entry number 4709
# INFO:root:Log entry number 4710
# INFO:root:Log entry number 4711
# INFO:root:Log entry number 4712
# INFO:root:Log entry number 4713
# INFO:root:Log entry number 4714
# INFO:root:Log entry number 4715
# INFO:root:Log entry number 4716
# INFO:root:Log entry number 4717
# INFO:root:Log entry number 4718
# INFO:root:Log entry number 4719
# INFO:root:Log entry number 4720
# INFO:root:Log entry number 4721
# INFO:root:Log entry number 4722
# INFO:root:Log entry number 4723
# INFO:root:Log entry number 4724
# INFO:root:Log entry number 4725
# INFO:root:Log entry number 4726
# INFO:root:Log entry number 4727
# INFO:root:Log entry number 4728
# INFO:root:Log entry number 4729
# INFO:root:Log entry number 4730
# INFO:root:Log entry number 4731
# INFO:root:Log entry number 4732
# INFO:root:Log entry number 4733
# INFO:root:Log entry number 4734
# INFO:root:Log entry number 4735
# INFO:root:Log entry number 4736
# INFO:root:Log entry number 4737
# INFO:root:Log entry number 4738
# INFO:root:Log entry number 4739
# INFO:root:Log entry number 4740
# INFO:root:Log entry number 4741
# INFO:root:Log entry number 4742
# INFO:root:Log entry number 4743
# INFO:root:Log entry number 4744
# INFO:root:Log entry number 4745
# INFO:root:Log entry number 4746
# INFO:root:Log entry number 4747
# INFO:root:Log entry number 4748
# INFO:root:Log entry number 4749
# INFO:root:Log entry number 4750
# INFO:root:Log entry number 4751
# INFO:root:Log entry number 4752
# INFO:root:Log entry number 4753
# INFO:root:Log entry number 4754
# INFO:root:Log entry number 4755
# INFO:root:Log entry number 4756
# INFO:root:Log entry number 4757
# INFO:root:Log entry number 4758
# INFO:root:Log entry number 4759
# INFO:root:Log entry number 4760
# INFO:root:Log entry number 4761
# INFO:root:Log entry number 4762
# INFO:root:Log entry number 4763
# INFO:root:Log entry number 4764
# INFO:root:Log entry number 4765
# INFO:root:Log entry number 4766
# INFO:root:Log entry number 4767
# INFO:root:Log entry number 4768
# INFO:root:Log entry number 4769
# INFO:root:Log entry number 4770
# INFO:root:Log entry number 4771
# INFO:root:Log entry number 4772
# INFO:root:Log entry number 4773
# INFO:root:Log entry number 4774
# INFO:root:Log entry number 4775
# INFO:root:Log entry number 4776
# INFO:root:Log entry number 4777
# INFO:root:Log entry number 4778
# INFO:root:Log entry number 4779
# INFO:root:Log entry number 4780
# INFO:root:Log entry number 4781
# INFO:root:Log entry number 4782
# INFO:root:Log entry number 4783
# INFO:root:Log entry number 4784
# INFO:root:Log entry number 4785
# INFO:root:Log entry number 4786
# INFO:root:Log entry number 4787
# INFO:root:Log entry number 4788
# INFO:root:Log entry number 4789
# INFO:root:Log entry number 4790
# INFO:root:Log entry number 4791
# INFO:root:Log entry number 4792
# INFO:root:Log entry number 4793
# INFO:root:Log entry number 4794
# INFO:root:Log entry number 4795
# INFO:root:Log entry number 4796
# INFO:root:Log entry number 4797
# INFO:root:Log entry number 4798
# INFO:root:Log entry number 4799
# INFO:root:Log entry number 4800
# INFO:root:Log entry number 4801
# INFO:root:Log entry number 4802
# INFO:root:Log entry number 4803
# INFO:root:Log entry number 4804
# INFO:root:Log entry number 4805
# INFO:root:Log entry number 4806
# INFO:root:Log entry number 4807
# INFO:root:Log entry number 4808
# INFO:root:Log entry number 4809
# INFO:root:Log entry number 4810
# INFO:root:Log entry number 4811
# INFO:root:Log entry number 4812
# INFO:root:Log entry number 4813
# INFO:root:Log entry number 4814
# INFO:root:Log entry number 4815
# INFO:root:Log entry number 4816
# INFO:root:Log entry number 4817
# INFO:root:Log entry number 4818
# INFO:root:Log entry number 4819
# INFO:root:Log entry number 4820
# INFO:root:Log entry number 4821
# INFO:root:Log entry number 4822
# INFO:root:Log entry number 4823
# INFO:root:Log entry number 4824
# INFO:root:Log entry number 4825
# INFO:root:Log entry number 4826
# INFO:root:Log entry number 4827
# INFO:root:Log entry number 4828
# INFO:root:Log entry number 4829
# INFO:root:Log entry number 4830
# INFO:root:Log entry number 4831
# INFO:root:Log entry number 4832
# INFO:root:Log entry number 4833
# INFO:root:Log entry number 4834
# INFO:root:Log entry number 4835
# INFO:root:Log entry number 4836
# INFO:root:Log entry number 4837
# INFO:root:Log entry number 4838
# INFO:root:Log entry number 4839
# INFO:root:Log entry number 4840
# INFO:root:Log entry number 4841
# INFO:root:Log entry number 4842
# INFO:root:Log entry number 4843
# INFO:root:Log entry number 4844
# INFO:root:Log entry number 4845
# INFO:root:Log entry number 4846
# INFO:root:Log entry number 4847
# INFO:root:Log entry number 4848
# INFO:root:Log entry number 4849
# INFO:root:Log entry number 4850
# INFO:root:Log entry number 4851
# INFO:root:Log entry number 4852
# INFO:root:Log entry number 4853
# INFO:root:Log entry number 4854
# INFO:root:Log entry number 4855
# INFO:root:Log entry number 4856
# INFO:root:Log entry number 4857
# INFO:root:Log entry number 4858
# INFO:root:Log entry number 4859
# INFO:root:Log entry number 4860
# INFO:root:Log entry number 4861
# INFO:root:Log entry number 4862
# INFO:root:Log entry number 4863
# INFO:root:Log entry number 4864
# INFO:root:Log entry number 4865
# INFO:root:Log entry number 4866
# INFO:root:Log entry number 4867
# INFO:root:Log entry number 4868
# INFO:root:Log entry number 4869
# INFO:root:Log entry number 4870
# INFO:root:Log entry number 4871
# INFO:root:Log entry number 4872
# INFO:root:Log entry number 4873
# INFO:root:Log entry number 4874
# INFO:root:Log entry number 4875
# INFO:root:Log entry number 4876
# INFO:root:Log entry number 4877
# INFO:root:Log entry number 4878
# INFO:root:Log entry number 4879
# INFO:root:Log entry number 4880
# INFO:root:Log entry number 4881
# INFO:root:Log entry number 4882
# INFO:root:Log entry number 4883
# INFO:root:Log entry number 4884
# INFO:root:Log entry number 4885
# INFO:root:Log entry number 4886
# INFO:root:Log entry number 4887
# INFO:root:Log entry number 4888
# INFO:root:Log entry number 4889
# INFO:root:Log entry number 4890
# INFO:root:Log entry number 4891
# INFO:root:Log entry number 4892
# INFO:root:Log entry number 4893
# INFO:root:Log entry number 4894
# INFO:root:Log entry number 4895
# INFO:root:Log entry number 4896
# INFO:root:Log entry number 4897
# INFO:root:Log entry number 4898
# INFO:root:Log entry number 4899
# INFO:root:Log entry number 4900
# INFO:root:Log entry number 4901
# INFO:root:Log entry number 4902
# INFO:root:Log entry number 4903
# INFO:root:Log entry number 4904
# INFO:root:Log entry number 4905
# INFO:root:Log entry number 4906
# INFO:root:Log entry number 4907
# INFO:root:Log entry number 4908
# INFO:root:Log entry number 4909
# INFO:root:Log entry number 4910
# INFO:root:Log entry number 4911
# INFO:root:Log entry number 4912
# INFO:root:Log entry number 4913
# INFO:root:Log entry number 4914
# INFO:root:Log entry number 4915
# INFO:root:Log entry number 4916
# INFO:root:Log entry number 4917
# INFO:root:Log entry number 4918
# INFO:root:Log entry number 4919
# INFO:root:Log entry number 4920
# INFO:root:Log entry number 4921
# INFO:root:Log entry number 4922
# INFO:root:Log entry number 4923
# INFO:root:Log entry number 4924
# INFO:root:Log entry number 4925
# INFO:root:Log entry number 4926
# INFO:root:Log entry number 4927
# INFO:root:Log entry number 4928
# INFO:root:Log entry number 4929
# INFO:root:Log entry number 4930
# INFO:root:Log entry number 4931
# INFO:root:Log entry number 4932
# INFO:root:Log entry number 4933
# INFO:root:Log entry number 4934
# INFO:root:Log entry number 4935
# INFO:root:Log entry number 4936
# INFO:root:Log entry number 4937
# INFO:root:Log entry number 4938
# INFO:root:Log entry number 4939
# INFO:root:Log entry number 4940
# INFO:root:Log entry number 4941
# INFO:root:Log entry number 4942
# INFO:root:Log entry number 4943
# INFO:root:Log entry number 4944
# INFO:root:Log entry number 4945
# INFO:root:Log entry number 4946
# INFO:root:Log entry number 4947
# INFO:root:Log entry number 4948
# INFO:root:Log entry number 4949
# INFO:root:Log entry number 4950
# INFO:root:Log entry number 4951
# INFO:root:Log entry number 4952
# INFO:root:Log entry number 4953
# INFO:root:Log entry number 4954
# INFO:root:Log entry number 4955
# INFO:root:Log entry number 4956
# INFO:root:Log entry number 4957
# INFO:root:Log entry number 4958
# INFO:root:Log entry number 4959
# INFO:root:Log entry number 4960
# INFO:root:Log entry number 4961
# INFO:root:Log entry number 4962
# INFO:root:Log entry number 4963
# INFO:root:Log entry number 4964
# INFO:root:Log entry number 4965
# INFO:root:Log entry number 4966
# INFO:root:Log entry number 4967
# INFO:root:Log entry number 4968
# INFO:root:Log entry number 4969
# INFO:root:Log entry number 4970
# INFO:root:Log entry number 4971
# INFO:root:Log entry number 4972
# INFO:root:Log entry number 4973
# INFO:root:Log entry number 4974
# INFO:root:Log entry number 4975
# INFO:root:Log entry number 4976
# INFO:root:Log entry number 4977
# INFO:root:Log entry number 4978
# INFO:root:Log entry number 4979
# INFO:root:Log entry number 4980
# INFO:root:Log entry number 4981
# INFO:root:Log entry number 4982
# INFO:root:Log entry number 4983
# INFO:root:Log entry number 4984
# INFO:root:Log entry number 4985
# INFO:root:Log entry number 4986
# INFO:root:Log entry number 4987
# INFO:root:Log entry number 4988
# INFO:root:Log entry number 4989
# INFO:root:Log entry number 4990
# INFO:root:Log entry number 4991
# INFO:root:Log entry number 4992
# INFO:root:Log entry number 4993
# INFO:root:Log entry number 4994
# INFO:root:Log entry number 4995
# INFO:root:Log entry number 4996
# INFO:root:Log entry number 4997
# INFO:root:Log entry number 4998
# INFO:root:Log entry number 4999

# %% [markdown]
# ## 19. WAP that handles both index error and key error using try - except block.

# %%
my_list = [10, 20, 30]
my_dict = {"name": "Ajay", "age": 25}

try:
    # Attempt to access an invalid list index
    index = int(input("Enter list index to access: "))
    print("List value:", my_list[index])

    # Attempt to access a non-existent dictionary key
    key = input("Enter dictionary key to access: ")
    print("Dictionary value:", my_dict[key])

except IndexError:
    print("Error: The index you entered is out of range.")

except KeyError:
    print("Error: The key you entered does not exist in the dictionary.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter list index to access: 1
# List value: 20
# Enter dictionary key to access: name
# Dictionary value: Ajay

# %%
my_list = [10, 20, 30]
my_dict = {"name": "Ajay", "age": 25}

try:
    # Attempt to access an invalid list index
    index = int(input("Enter list index to access: "))
    print("List value:", my_list[index])

    # Attempt to access a non-existent dictionary key
    key = input("Enter dictionary key to access: ")
    print("Dictionary value:", my_dict[key])

except IndexError:
    print("Error: The index you entered is out of range.")

except KeyError:
    print("Error: The key you entered does not exist in the dictionary.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter list index to access: 5
# Error: The index you entered is out of range.

# %%
my_list = [10, 20, 30]
my_dict = {"name": "Ajay", "age": 25}

try:
    # Attempt to access an invalid list index
    index = int(input("Enter list index to access: "))
    print("List value:", my_list[index])

    # Attempt to access a non-existent dictionary key
    key = input("Enter dictionary key to access: ")
    print("Dictionary value:", my_dict[key])

except IndexError:
    print("Error: The index you entered is out of range.")

except KeyError:
    print("Error: The key you entered does not exist in the dictionary.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter list index to access: 2
# List value: 30
# Enter dictionary key to access: class
# Error: The key you entered does not exist in the dictionary.

# %% [markdown]
# ## 20. How would you open a file and read its content using a context manager in Python?

# %%
# Open and read a file using a context manager
with open("example.txt", "r") as file:
    content = file.read()

print("File content:\n", content)
# Out:
# File content:
#  Hello, this is my first file!
# This is new content being appended.

# %% [markdown]
# ## 21. WAP that reads a file and prints the number of occurences of a specific word.

# %%
file_path = "example.txt"
search_word = "Hello"

try:
    with open(file_path, "r") as file:
        content = file.read().lower()
        word_count = content.count(search_word.lower())
        print(f"The word '{search_word}' appears {word_count} times in the file.")
except FileNotFoundError:
    print("File not found.")
# Out:
# The word 'Hello' appears 1 times in the file.

# %% [markdown]
# ## 22. How can you check if a file is empty before attempting to read its contents?

# %%
import os

file_path = "example.txt"


if os.path.exists(file_path):
    if os.path.getsize(file_path) == 0:
        print("The file is empty.")
    else:
        with open(file_path, "r") as file:
            content = file.read()
            print("File content:")
            print(content)
else:
    print("File not found.")
# Out:
# File content:
# Hello, this is my first file!
# This is new content being appended.

# %% [markdown]
# ## 23. WAP that writes to a log file when an error occurs during file handling?

# %%
import logging

# Configure logging
logging.basicConfig(
    filename="file_errors.log",          # Log file name
    level=logging.ERROR,                 # Only log errors and above
    format="%(asctime)s - %(levelname)s - %(message)s"  # Log format
)

try:
    # Attempt to open a file that might not exist
    with open("non_existing_file.txt", "r") as file:
        content = file.read()

except FileNotFoundError as e:
    logging.error(f"File not found: {e}")
    print("Error: File not found. Check log for details.")

except PermissionError as e:
    logging.error(f"Permission denied: {e}")
    print("Error: Permission denied. Check log for details.")

except Exception as e:
    logging.error(f"Unexpected error: {e}")
    print("Error: An unexpected error occurred. Check log for details.")
# Out:
# ERROR:root:File not found: [Errno 2] No such file or directory: 'non_existing_file.txt'
# Error: File not found. Check log for details.
